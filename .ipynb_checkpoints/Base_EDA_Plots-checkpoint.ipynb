# %%
import pandas as pd 
import numpy as np

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
train.popularity.value_counts()
# Out:
# 4    15231
# 3     2166
# 5      472
# 1      323
# 0       16
# Name: popularity, dtype: int64

# %%
train= train[train['popularity']!=0]

# %%
train.columns
# Out:
# Index(['Store_Ratio', 'Basket_Ratio', 'Category_1', 'Store_Score',
#        'Category_2', 'Store_Presence', 'Score_1', 'Score_2', 'Score_3',
#        'Score_4', 'time', 'popularity'],
#       dtype='object')

# %%
x = train[train['popularity']==1]

# %%
x.nunique()
# Out:
# Store_Ratio       215
# Basket_Ratio      243
# Category_1         12
# Store_Score       258
# Category_2          2
# Store_Presence    177
# Score_1           176
# Score_2           167
# Score_3           223
# Score_4           261
# time              256
# popularity          1
# dtype: int64

# %%
train.nunique()
# Out:
# Store_Ratio        1052
# Basket_Ratio       1991
# Category_1           12
# Store_Score       10745
# Category_2            2
# Store_Presence     2830
# Score_1            3668
# Score_2            1383
# Score_3            1591
# Score_4           12942
# time              12745
# popularity            4
# dtype: int64

# %%
train.head()
# Out:
#    Store_Ratio  Basket_Ratio  Category_1  Store_Score  Category_2  \
# 0        0.407       0.00380           2      -35.865           1
# 1        0.234       0.10500           0      -19.884           1
# 2        0.668       0.72600           9       -7.512           1
# 3        0.184       0.00561           4      -34.357           1
# 4        0.231       0.13100           6      -22.842           1
#
#    Store_Presence  Score_1  Score_2  Score_3  Score_4    time  popularity
# 0          0.9920    0.944   0.0988   0.1100  113.911  189125           4
# 1          0.9440    0.900   0.1290   0.0382   76.332  186513           4
# 2          0.0387    0.000   0.1340   0.4530  124.075  172143           4
# 3          0.8490    0.931   0.1110   0.0641   79.037  184000           5
# 4          0.9370    0.000   0.1090   0.0677  109.560  186507           3

# %%
sns.distplot(train['Store_Ratio'],color="blue")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Store_Ratio', ylabel='Density'>

# %%
sns.distplot(test['Store_Ratio'],color="green")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Store_Ratio', ylabel='Density'>

# %%
temp = train[train['Basket_Ratio']==0]
# Out:
# 0

# %%
sns.distplot(train['Basket_Ratio'],color="blue")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Basket_Ratio', ylabel='Density'>

# %%
sns.distplot(test['Basket_Ratio'],color="blue")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Basket_Ratio', ylabel='Density'>

# %%
sns.distplot(x['Basket_Ratio'],color="blue")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Basket_Ratio', ylabel='Density'>

# %%
# Out:
#        Store_Ratio  Basket_Ratio  Category_1  Store_Score  Category_2  \
# count   323.000000    323.000000  323.000000   323.000000  323.000000
# mean      0.349232      0.265482    5.275542   -19.388551    0.712074
# std       0.189701      0.272486    3.506195     8.639259    0.453499
# min       0.059900      0.003180    0.000000   -45.242000    0.000000
# 25%       0.188000      0.054550    2.000000   -25.971500    0.000000
# 50%       0.316000      0.153000    5.000000   -19.346000    1.000000
# 75%       0.506500      0.407500    9.000000   -12.066000    1.000000
# max       0.998000      1.000000   11.000000    -3.827000    1.000000
#
#        Store_Presence     Score_1     Score_2     Score_3     Score_4  \
# count      323.000000  323.000000  323.000000  323.000000  323.000000
# mean         0.751829    0.602992    0.182527    0.212988  105.858985
# std          0.319605    0.414529    0.181585    0.205302   30.234466
# ...

# %%
import matplotlib.pyplot as plt
for column in test.columns:
  print(column)
  fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(18,6))
  sns.distplot(train[column],ax=ax[0],color="blue")
  sns.distplot(test[column],ax=ax[1],color="green")
  plt.show()
# Out:
# Store_Ratio
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Basket_Ratio
# ...

# %%
train.boxplot(column=['time'])
# Out:
# <AxesSubplot:>

# %%
train=train[train['time']<2*1e6]
train.boxplot(column=['time'])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(train['time'],color="blue")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='time', ylabel='Density'>

# %%
dummy = train[train['time']>1.75*1e6]
dummy.popularity.value_counts()
# Out:
# 3    1
# Name: popularity, dtype: int64

# %%
np.max(test['time'])
# Out:
# 1782178

# %%
dummy1 = train[train['popularity']==3]
sns.distplot(dummy1['time'],color="blue")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='time', ylabel='Density'>

# %%
dummy1.boxplot(column=['time'])
# Out:
# <AxesSubplot:>

# %%
np.max(train['time'])
# Out:
# 1804691

# %%
testing = train[train['time']==1804691]
testing
# Out:
#        Store_Ratio  Basket_Ratio  Category_1  Store_Score  Category_2  \
# 15885        0.218        0.0224           5      -37.484           0
#
#        Store_Presence  Score_1  Score_2  Score_3  Score_4     time  popularity
# 15885           0.804     0.97    0.111   0.0505   66.399  1804691           3

# %%
dummy2 = train[train['popularity']==1]
sns.distplot(dummy2['time'],color="blue")
# Out:
# /home/prateek/vpy/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='time', ylabel='Density'>

# %%
dummy2.boxplot(column=['time'])
# Out:
# <AxesSubplot:>

# %%
train.basket
